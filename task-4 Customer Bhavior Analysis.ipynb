# %%
# !pip install pandas numpy matplotlib seaborn scipy scikit-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import chi2_contingency

plt.style.use('ggplot')

# %%
df = pd.read_csv("C:/Users/hp/Downloads/customer _data.csv")
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.head() 
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Customer ID            250000 non-null  int64
#  1   Purchase Date          250000 non-null  object
#  2   Product Category       250000 non-null  object
#  3   Product Price          250000 non-null  int64
#  4   Quantity               250000 non-null  int64
#  5   Total Purchase Amount  250000 non-null  int64
#  6   Payment Method         250000 non-null  object
#  7   Customer Age           250000 non-null  int64
#  8   Returns                202404 non-null  float64
#  9   Customer Name          250000 non-null  object
#  10  Age                    250000 non-null  int64
#  11  Gender                 250000 non-null  object
#  12  Churn                  250000 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 24.8+ MB
# ...

# %%
df.shape
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.isnull().sum()
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.fillna(0, inplace=True)
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.shape
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df.describe()
df
# Out:
#         Customer ID        Purchase Date Product Category  Product Price  \
# 0             46251  2020-09-08 09:38:32      Electronics             12
# 1             46251  2022-03-05 12:56:35             Home            468
# 2             46251  2022-05-23 18:18:01             Home            288
# 3             46251  2020-11-12 13:13:29         Clothing            196
# 4             13593  2020-11-27 17:55:11             Home            449
# ...             ...                  ...              ...            ...
# 249995        33308  2023-08-10 13:39:06         Clothing            279
# 249996        48835  2021-11-23 01:30:42             Home             27
# 249997        21019  2020-07-02 14:04:48             Home             17
# 249998        49234  2020-12-30 02:02:40            Books            398
# 249999        16971  2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=20)

plt.title("Customer Age Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x='Gender', data=df)

plt.title("Gender Distribution")
plt.show()

# %%
category_sales = df.groupby('Product Category')['Total Purchase Amount'].sum()

category_sales.sort_values(ascending=False).plot(
kind='bar',
figsize=(8,5)
)

plt.title("Sales by Product Category")
plt.show()

# %%
payment = df['Payment Method'].value_counts()

payment.plot(
kind='pie',
autopct='%1.1f%%',
figsize=(7,7)
)

plt.title("Payment Method Usage")
plt.ylabel("")
plt.show()

# %%
sns.countplot(x='Churn', data=df)

plt.title("Customer Churn Distribution")
plt.show()

# %%
gender_spending = df.groupby('Gender')['Total Purchase Amount'].mean()

gender_spending.plot(kind='bar')

plt.title("Average Spending by Gender")
plt.show()

# %%
df['Purchase Date'] = pd.to_datetime(df['Purchase Date'])
df
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 0             46251 2020-09-08 09:38:32      Electronics             12
# 1             46251 2022-03-05 12:56:35             Home            468
# 2             46251 2022-05-23 18:18:01             Home            288
# 3             46251 2020-11-12 13:13:29         Clothing            196
# 4             13593 2020-11-27 17:55:11             Home            449
# ...             ...                 ...              ...            ...
# 249995        33308 2023-08-10 13:39:06         Clothing            279
# 249996        48835 2021-11-23 01:30:42             Home             27
# 249997        21019 2020-07-02 14:04:48             Home             17
# 249998        49234 2020-12-30 02:02:40            Books            398
# 249999        16971 2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
df['Month'] = df['Purchase Date'].dt.month
df
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 0             46251 2020-09-08 09:38:32      Electronics             12
# 1             46251 2022-03-05 12:56:35             Home            468
# 2             46251 2022-05-23 18:18:01             Home            288
# 3             46251 2020-11-12 13:13:29         Clothing            196
# 4             13593 2020-11-27 17:55:11             Home            449
# ...             ...                 ...              ...            ...
# 249995        33308 2023-08-10 13:39:06         Clothing            279
# 249996        48835 2021-11-23 01:30:42             Home             27
# 249997        21019 2020-07-02 14:04:48             Home             17
# 249998        49234 2020-12-30 02:02:40            Books            398
# 249999        16971 2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
monthly_sales = df.groupby('Month')['Total Purchase Amount'].sum()

plt.figure(figsize=(10,5))

monthly_sales.plot(marker='o')

plt.title("Monthly Sales Trend")

plt.show()

# %%
latest_date = df['Purchase Date'].max()
latest_date
# Out:
# Timestamp('2023-09-15 12:24:08')

# %%
rfm = df.groupby('Customer ID').agg({

'Purchase Date': lambda x: (latest_date - x.max()).days,

'Customer ID':'count',

'Total Purchase Amount':'sum'

})
rfm
# Out:
#              Purchase Date  Customer ID  Total Purchase Amount
# Customer ID
# 1                       57            1                   3491
# 2                      298            3                   7988
# 3                       88            8                  22587
# 4                      126            4                   8715
# 5                      170            8                  12524
# ...                    ...          ...                    ...
# 49996                  271            4                  14044
# 49997                   49            8                  22431
# 49998                   11            4                   8610
# 49999                  419            2                   6984
# 50000                  126            2                   4116
#
# [49673 rows x 3 columns]

# %%
rfm.columns = ['Recency','Frequency','Monetary']
rfm
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# 1                 57          1      3491
# 2                298          3      7988
# 3                 88          8     22587
# 4                126          4      8715
# 5                170          8     12524
# ...              ...        ...       ...
# 49996            271          4     14044
# 49997             49          8     22431
# 49998             11          4      8610
# 49999            419          2      6984
# 50000            126          2      4116
#
# [49673 rows x 3 columns]

# %%
rfm.head()
rfm
# Out:
#              Recency  Frequency  Monetary
# Customer ID
# 1                 57          1      3491
# 2                298          3      7988
# 3                 88          8     22587
# 4                126          4      8715
# 5                170          8     12524
# ...              ...        ...       ...
# 49996            271          4     14044
# 49997             49          8     22431
# 49998             11          4      8610
# 49999            419          2      6984
# 50000            126          2      4116
#
# [49673 rows x 3 columns]

# %%
rfm['R_Score'] = pd.qcut(
rfm['Recency'],
4,
labels=[4,3,2,1]
)

rfm['F_Score'] = pd.qcut(
rfm['Frequency'].rank(method='first'),
4,
labels=[1,2,3,4]
)

rfm['M_Score'] = pd.qcut(
rfm['Monetary'],
4,
labels=[1,2,3,4]
)
rfm
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score
# Customer ID
# 1                 57          1      3491       4       1       1
# 2                298          3      7988       2       1       1
# 3                 88          8     22587       3       4       4
# 4                126          4      8715       3       2       1
# 5                170          8     12524       3       4       2
# ...              ...        ...       ...     ...     ...     ...
# 49996            271          4     14044       2       2       3
# 49997             49          8     22431       4       4       4
# 49998             11          4      8610       4       2       1
# 49999            419          2      6984       1       1       1
# 50000            126          2      4116       3       1       1
#
# [49673 rows x 6 columns]

# %%
rfm['RFM_Score'] = (
rfm['R_Score'].astype(str)+
rfm['F_Score'].astype(str)+
rfm['M_Score'].astype(str)
)

rfm.head()
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score
# Customer ID
# 1                 57          1      3491       4       1       1       411
# 2                298          3      7988       2       1       1       211
# 3                 88          8     22587       3       4       4       344
# 4                126          4      8715       3       2       1       321
# 5                170          8     12524       3       4       2       342

# %%
rfm['Segment'] = 'Regular'

rfm.loc[rfm['RFM_Score']=='444','Segment']='Champion'
rfm
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score  \
# Customer ID
# 1                 57          1      3491       4       1       1       411
# 2                298          3      7988       2       1       1       211
# 3                 88          8     22587       3       4       4       344
# 4                126          4      8715       3       2       1       321
# 5                170          8     12524       3       4       2       342
# ...              ...        ...       ...     ...     ...     ...       ...
# 49996            271          4     14044       2       2       3       223
# 49997             49          8     22431       4       4       4       444
# 49998             11          4      8610       4       2       1       421
# 49999            419          2      6984       1       1       1       111
# 50000            126          2      4116       3       1       1       311
#
#               Segment
# Customer ID
# ...

# %%
rfm['Segment'].value_counts()
rfm
# Out:
#              Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score  \
# Customer ID
# 1                 57          1      3491       4       1       1       411
# 2                298          3      7988       2       1       1       211
# 3                 88          8     22587       3       4       4       344
# 4                126          4      8715       3       2       1       321
# 5                170          8     12524       3       4       2       342
# ...              ...        ...       ...     ...     ...     ...       ...
# 49996            271          4     14044       2       2       3       223
# 49997             49          8     22431       4       4       4       444
# 49998             11          4      8610       4       2       1       421
# 49999            419          2      6984       1       1       1       111
# 50000            126          2      4116       3       1       1       311
#
#               Segment
# Customer ID
# ...

# %%
rfm['Segment'].value_counts().plot(
kind='bar',
figsize=(8,5)
)

plt.title("Customer Segments")
plt.show()

# %%
df['Frequency_Group'] = pd.cut(
df['Quantity'],
bins=[0,2,5,10],
labels=['Low','Medium','High']
)
df
# Out:
#         Customer ID       Purchase Date Product Category  Product Price  \
# 0             46251 2020-09-08 09:38:32      Electronics             12
# 1             46251 2022-03-05 12:56:35             Home            468
# 2             46251 2022-05-23 18:18:01             Home            288
# 3             46251 2020-11-12 13:13:29         Clothing            196
# 4             13593 2020-11-27 17:55:11             Home            449
# ...             ...                 ...              ...            ...
# 249995        33308 2023-08-10 13:39:06         Clothing            279
# 249996        48835 2021-11-23 01:30:42             Home             27
# 249997        21019 2020-07-02 14:04:48             Home             17
# 249998        49234 2020-12-30 02:02:40            Books            398
# 249999        16971 2021-03-13 16:28:35      Electronics            425
#
#         Quantity  Total Purchase Amount Payment Method  Customer Age  Returns  \
# ...

# %%
contingency_table = pd.crosstab(
df['Frequency_Group'],
df['Churn']
)

contingency_table
# Out:
# Churn                 0      1
# Frequency_Group
# Low               80138  19991
# Medium           119988  29883

# %%
chi2,p,dof,expected = chi2_contingency(
contingency_table
)

print("Chi Square Value:",chi2)
print("P Value:",p)
# Out:
# Chi Square Value: 0.023991122694332543
# P Value: 0.8769075014005167

# %%
if p < 0.05:
    print("Reject Null Hypothesis")
    print("Purchase Frequency affects Churn")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Fail to Reject Null Hypothesis

# %%
print("1. Electronics category generates highest sales")
print("2. Majority customers belong to age 25-45")
print("3. Credit Card is preferred payment method")
print("4. Low-frequency customers show higher churn")
print("5. Customer retention improves with repeat purchases")
# Out:
# 1. Electronics category generates highest sales
# 2. Majority customers belong to age 25-45
# 3. Credit Card is preferred payment method
# 4. Low-frequency customers show higher churn
# 5. Customer retention improves with repeat purchases

# %%
df.to_csv(
"customer_behavior_analysis_final.csv",
index=False
)

print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully
